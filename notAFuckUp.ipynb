# %%
import tmdbsimple as tmdb
import pandas as pd
tmdb.API_KEY = 'e89550393e2861f05fdcc0ee49a1d875'


#features available on https://pypi.org/project/tmdb3/

# %%
movie_list = pd.DataFrame()
lst = []
nonexist = []
for i in range(100):     #get 10000000 movies and add them to movie_list
    try:
        response = tmdb.Movies(i).info()
        if(response['release_date'] > '2000-01-01'):
            lst.append(response)
    except:
        nonexist.append(i)
        print('%d does not exist' % i)
# Out:
# 0 does not exist
# 1 does not exist
# 4 does not exist
# 7 does not exist
# 10 does not exist
# 23 does not exist
# 29 does not exist
# 34 does not exist
# 36 does not exist
# 37 does not exist
# 39 does not exist
# 40 does not exist
# 41 does not exist
# 42 does not exist
# 43 does not exist
# 44 does not exist
# 45 does not exist
# 46 does not exist
# 47 does not exist
# 48 does not exist
# 49 does not exist
# 50 does not exist
# 51 does not exist
# 52 does not exist
# 53 does not exist
# 54 does not exist
# 56 does not exist
# 57 does not exist
# 60 does not exist
# 61 does not exist
# 72 does not exist
# 84 does not exist

# %%
lst.append(tmdb.Movies(315635).info())


g = pd.DataFrame()

# %%
response = tmdb.Movies(315635).info()

response['genres']

lst

g.append(lst)
# Out:
#     adult                     backdrop_path  \
# 0   False  /udvB86uyzJ6P9vmB83WfrCbnmnI.jpg
# 1   False                              None
# 2   False  /2Xh7cVe9beCn04ouN9IGfK8WTok.jpg
# 3   False  /5k89pUmFMZ82yPiL7bqxaFiDqaa.jpg
# 4   False  /pkCC3myn5QuoLzplTlvZLB0w2AU.jpg
# 5   False  /caLMOD3ZJ3V7qjlxDXrzlJfBLgD.jpg
# 6   False  /8AUQ7YlJJA9C8kWk8P4YNHIcFDE.jpg
# 7   False  /kkS8PKa8c134vXsj2fQkNqOaCXU.jpg
# 8   False  /shg7ZGAGVxhM9ZfOtV6bp93QZwt.jpg
# 9   False  /osVUxR3HdccQG8yBKX3VWp8nVFv.jpg
# 10  False  /tie8vA3q3Q9BB5RlMlexRvv9xoh.jpg
# 11  False  /tNpqx8PcFdgKgheUWmNqNF9RNGm.jpg
# 12  False  /1dXTsaFxHoF9cas08UjAqE8NqOW.jpg
# 13  False  /AuXC0SsPZaAfddtSMnxSnbEeEjR.jpg
# 14  False  /yD3gXOtGmXnbJBPLgqluZU2QF5c.jpg
# 15  False  /8rbvmhGmUqEjLmo2mDycTazEaAc.jpg
# 16  False  /3QFJkOSvFOYs8kUhXfJ8nE4UBU6.jpg
# 17  False  /jq4dyVYsCGQRTXKDLoqZwg4tbIr.jpg
# 18  False  /lz1iJlKRBMtE6uHauUneX7THa0c.jpg
# 19  False  /iL484fDDFtszNVmYKBFmPP57wEA.jpg
# ...

# %%
movie_data = pd.read_csv('MovieData108.csv')
# Out:
#                                        movie_name  production_year  \
# 0                          Madea's Family Reunion             2006
# 1                                          Krrish             2006
# 2                                End of the Spear             2006
# 3                        A Prairie Home Companion             2006
# 4                                         Saw III             2006
# 5                           Employee of the Month             2006
# 6                                          Edmond             2006
# 7                                Peaceful Warrior             2006
# 8                                        Turistas             2006
# 9                          Kabhi Alvida Naa Kehna             2006
# 10                            Jackass: Number Two             2006
# 11                              Copying Beethoven             2006
# 12                         For Your Consideration             2006
# ...

# %%
search = tmdb.Search()
response = search.movie(query = 'avengers')
for s in search.results:
    print(s['title'], s['release_date'], s['id'])
# Out:
# Avengers: Endgame 2019-04-24 299534
# The Avengers 2012-04-25 24428
# Avengers: Infinity War 2018-04-25 299536
# Avengers: Age of Ultron 2015-04-22 99861
# Ultimate Avengers 2006-02-21 14609
# The Avengers 1998-08-13 9320
# Ultimate Avengers 2 2006-08-08 14611
# Bikini Avengers 2015-02-24 347158
# Avengers Grimm 2015-03-17 323660
# Avengers Grimm: Time Wars 2018-05-01 521720
# Next Avengers: Heroes of Tomorrow 2008-09-02 14613
# Avengers of Justice: Farce Wars 2018-07-20 538153
# LEGO Marvel Super Heroes: Avengers Reassembled! 2015-11-16 368304
# SuperBobrovs. People Avengers 2017-12-25 516339
# Alien Avengers 1996-08-03 58906
# Avengers Confidential: Black Widow & Punisher 2014-03-25 257346
# Masked Avengers 1981-05-15 63441
# Crippled Avengers 1978-12-20 40081
# Avengers from Hell 1981-04-02 157421
# Ninja Avengers 1987-01-01 416101

# %%
movie_data.append(tmdb.Movies(299534).info(),ignore_index=True)
# Out:
#                                        movie_name  production_year  \
# 0                          Madea's Family Reunion           2006.0
# 1                                          Krrish           2006.0
# 2                                End of the Spear           2006.0
# 3                        A Prairie Home Companion           2006.0
# 4                                         Saw III           2006.0
# 5                           Employee of the Month           2006.0
# 6                                          Edmond           2006.0
# 7                                Peaceful Warrior           2006.0
# 8                                        Turistas           2006.0
# 9                          Kabhi Alvida Naa Kehna           2006.0
# 10                            Jackass: Number Two           2006.0
# 11                              Copying Beethoven           2006.0
# 12                         For Your Consideration           2006.0
# ...

# %%
super_heroes = movie_data[movie_data['creative_type'] == "Super Hero"]


movie_data['revenue'] = movie_data['domestic_box_office'] + movie_data['international_box_office']

# %%
super_heroes

super_heroes['profit'] = super_heroes['revenue'] - super_heroes['production_budget']
super_heroes[['movie_name','production_year','production_budget','revenue', 'profit', 'genre', 'sequel', 'creative_type']]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                             movie_name  production_year  \
# 75                              My Super Ex-Girlfriend             2006
# 88                                                Zoom             2006
# 157                              X-Men: The Last Stand             2006
# 159                                   Superman Returns             2006
# 300                                        Ghost Rider             2007
# 301          Fantastic Four: Rise of the Silver Surfer             2007
# ...

# %%
len(super_heroes)
# Out:
# 60

# %%
action = movie_data[movie_data['genre'] == "Action"]


action['profit'] = action['revenue'] - action['production_budget']
action[['movie_name','production_year','production_budget','revenue', 'profit', 'genre', 'sequel', 'creative_type']]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                                  movie_name  production_year  \
# 1                                    Krrish             2006
# 13                                    Crank             2006
# 26                               The Marine             2006
# 40                           Running Scared             2006
# 44                              Renaissance             2006
# 63                               BloodRayne             2006
# 74                              Ultraviolet             2006
# 76                                    Wu ji             2006
# ...

# %%
action.to_csv('actionMovies.csv')
super_heroes.to_csv('superheroMovies.csv')
